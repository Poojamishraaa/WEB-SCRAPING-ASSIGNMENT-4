# %%
from bs4 import BeautifulSoup
from selenium import webdriver
driver = webdriver.Chrome()
url = "https://www.billboard.com/charts/hot-100/"
driver.get(url)
soup = BeautifulSoup(driver.page_source, 'html.parser')
driver.quit()

SongNameArr=[]
for i in soup.select('.o-chart-results-list-row-container ul.o-chart-results-list-row h3#title-of-a-story'):
    SongName = i.text.strip()
    SongNameArr.append(SongName)

SongNameArr[0:]
# Out:
# ['Flowers',
#  'Kill Bill',
#  "Creepin'",
#  'Anti-Hero',
#  'Unholy',
#  'Die For You',
#  "I'm Good (Blue)",
#  'Rich Flex',
#  'As It Was',
#  'Just Wanna Rock',
#  'Made You Look',
#  'Golden Hour',
#  'Under The Influence',
#  'Something In The Orange',
#  'Cuff It',
#  'Rock And A Hard Place',
#  'Thank God',
#  'You Proof',
#  'Lavender Haze',
#  'Bad Habit',
#  'Thought You Should Know',
#  'Bzrp Music Sessions, Vol. 53',
#  'Escapism',
#  'Going, Going, Gone',
#  'Superhero (Heroes & Villains)',
#  'Calm Down',
#  'Last Night',
#  'Until I Found You',
#  'Wait In The Truck',
#  'The Kind Of Love We Make',
#  'I Like You (A Happier Song)',
#  'Shirt',
#  'Heart Like A Truck',
#  'Wait For U',
#  'Snooze',
#  'Sure Thing',
#  'Bebe Dame',
#  'Players',
#  'Tomorrow 2',
#  'Love Again',
#  'She Had Me At Heads Carolina',
#  'Dawns',
#  'Whiskey On You',
#  'Super Freaky Girl',
#  'Nobody Gets Me',
#  'Unstoppable',
#  'What My World Spins Around',
#  'Sunroof',
# ...

# %%
ArtNameArr=[]
for i in soup.select('.o-chart-results-list-row-container ul.o-chart-results-list-row span.c-label.a-no-trucate'):
    ArtName = i.text.strip()
    ArtNameArr.append(ArtName)

ArtNameArr[0:]
# Out:
# ['Miley Cyrus',
#  'SZA',
#  'Metro Boomin, The Weeknd & 21 Savage',
#  'Taylor Swift',
#  'Sam Smith & Kim Petras',
#  'The Weeknd',
#  'David Guetta & Bebe Rexha',
#  'Drake & 21 Savage',
#  'Harry Styles',
#  'Lil Uzi Vert',
#  'Meghan Trainor',
#  'JVKE',
#  'Chris Brown',
#  'Zach Bryan',
#  'Beyonce',
#  'Bailey Zimmerman',
#  'Kane Brown With Katelyn Brown',
#  'Morgan Wallen',
#  'Taylor Swift',
#  'Steve Lacy',
#  'Morgan Wallen',
#  'Bizarrap & Shakira',
#  'RAYE Featuring 070 Shake',
#  'Luke Combs',
#  'Metro Boomin, Future & Chris Brown',
#  'Rema & Selena Gomez',
#  'Morgan Wallen',
#  'Stephen Sanchez',
#  'HARDY Featuring Lainey Wilson',
#  'Luke Combs',
#  'Post Malone Featuring Doja Cat',
#  'SZA',
#  'Lainey Wilson',
#  'Future Featuring Drake & Tems',
#  'SZA',
#  'Miguel',
#  'Fuerza Regida X Grupo Frontera',
#  'Coi Leray',
#  'GloRilla & Cardi B',
#  'The Kid LAROI',
#  'Cole Swindell',
#  'Zach Bryan Featuring Maggie Rogers',
#  'Nate Smith',
# ...

# %%
LastWArr=[]
for i in soup.select('.chart-results-list .o-chart-results-list-row-container ul.o-chart-results-list-row > li.lrv-u-width-100p > ul > li:nth-child(4)'):
    LastW = i.text.strip()
    LastWArr.append(LastW)

LastWArr[0:]
# Out:
# ['1',
#  '2',
#  '4',
#  '3',
#  '5',
#  '7',
#  '6',
#  '8',
#  '9',
#  '12',
#  '14',
#  '10',
#  '16',
#  '11',
#  '15',
#  '19',
#  '18',
#  '20',
#  '30',
#  '17',
#  '27',
#  '13',
#  '22',
#  '25',
#  '21',
#  '28',
#  '-',
#  '29',
#  '23',
#  '35',
#  '24',
#  '26',
#  '33',
#  '34',
#  '31',
#  '39',
#  '32',
#  '49',
#  '37',
#  '-',
#  '41',
#  '-',
#  '46',
#  '36',
#  '38',
#  '43',
#  '40',
#  '42',
#  '45',
#  '48',
#  '44',
#  '51',
#  '47',
#  '73',
#  '53',
#  '54',
#  '55',
#  '-',
#  '62',
#  '59',
#  '-',
#  '61',
#  '58',
#  '-',
#  '60',
#  '63',
#  '66',
#  '57',
#  '70',
#  '69',
#  '-',
#  '56',
#  '65',
#  '72',
#  '68',
#  '76',
#  '79',
#  '67',
#  '92',
#  '-',
#  '77',
#  '81',
#  '75',
#  '71',
#  '96',
#  '-',
#  '78',
#  '88',
#  '98',
#  '89',
#  '95',
#  '-',
#  '52',
#  '94',
#  '91',
#  '-',
#  '85',
#  '83',
#  '-',
#  '-']

# %%
PeakPosArr=[]
for i in soup.select('.chart-results-list .o-chart-results-list-row-container ul.o-chart-results-list-row > li.lrv-u-width-100p > ul > li:nth-child(5)'):
    PeakPos = i.text.strip()
    PeakPosArr.append(PeakPos)

PeakPosArr[0:]
# Out:
# ['1',
#  '2',
#  '3',
#  '1',
#  '1',
#  '6',
#  '4',
#  '2',
#  '1',
#  '10',
#  '11',
#  '10',
#  '12',
#  '10',
#  '10',
#  '16',
#  '17',
#  '5',
#  '2',
#  '1',
#  '12',
#  '9',
#  '22',
#  '24',
#  '8',
#  '26',
#  '27',
#  '23',
#  '23',
#  '8',
#  '3',
#  '11',
#  '32',
#  '1',
#  '29',
#  '36',
#  '25',
#  '38',
#  '9',
#  '40',
#  '16',
#  '42',
#  '43',
#  '1',
#  '10',
#  '28',
#  '40',
#  '4',
#  '6',
#  '1',
#  '2',
#  '50',
#  '17',
#  '37',
#  '53',
#  '54',
#  '55',
#  '58',
#  '59',
#  '58',
#  '61',
#  '61',
#  '58',
#  '64',
#  '60',
#  '63',
#  '5',
#  '12',
#  '12',
#  '67',
#  '71',
#  '56',
#  '57',
#  '72',
#  '67',
#  '68',
#  '77',
#  '21',
#  '79',
#  '80',
#  '77',
#  '81',
#  '68',
#  '22',
#  '85',
#  '86',
#  '8',
#  '88',
#  '89',
#  '85',
#  '91',
#  '49',
#  '52',
#  '4',
#  '91',
#  '96',
#  '60',
#  '83',
#  '99',
#  '100']

# %%
WeOnChartArr=[]
for i in soup.select('.chart-results-list .o-chart-results-list-row-container ul.o-chart-results-list-row > li.lrv-u-width-100p > ul > li:nth-child(6)'):
    WeOnChart = i.text.strip()
    WeOnChartArr.append(WeOnChart)

WeOnChartArr[0:]
# Out:
# ['3',
#  '8',
#  '9',
#  '15',
#  '19',
#  '27',
#  '23',
#  '13',
#  '44',
#  '16',
#  '15',
#  '23',
#  '21',
#  '41',
#  '25',
#  '34',
#  '21',
#  '38',
#  '15',
#  '31',
#  '25',
#  '3',
#  '9',
#  '12',
#  '9',
#  '22',
#  '1',
#  '31',
#  '22',
#  '28',
#  '32',
#  '14',
#  '12',
#  '37',
#  '8',
#  '27',
#  '6',
#  '5',
#  '19',
#  '1',
#  '32',
#  '1',
#  '33',
#  '25',
#  '8',
#  '25',
#  '25',
#  '32',
#  '30',
#  '38',
#  '14',
#  '6',
#  '8',
#  '9',
#  '8',
#  '5',
#  '7',
#  '1',
#  '18',
#  '5',
#  '1',
#  '17',
#  '12',
#  '1',
#  '5',
#  '5',
#  '13',
#  '8',
#  '12',
#  '20',
#  '1',
#  '3',
#  '17',
#  '2',
#  '14',
#  '5',
#  '3',
#  '8',
#  '2',
#  '1',
#  '4',
#  '2',
#  '7',
#  '9',
#  '2',
#  '1',
#  '13',
#  '4',
#  '2',
#  '4',
#  '3',
#  '3',
#  '2',
#  '12',
#  '2',
#  '1',
#  '6',
#  '3',
#  '1',
#  '1']
